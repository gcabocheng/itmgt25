# %% [markdown]
# # Assignment: Libraries
#
# This problem set aims to develop your ability to use non-standard libraries such as NumPy, Pandas, Matplotlib, and requests.
#
# Please follow all instructions precisely.

# %% [markdown]
# ## Prerequisite: Install libraries
#
# To do this assignment, you need to have a few libraries installed. You already know how to install libraries in a basic Python virtual environment. In Anaconda, it is even easier.
#
# Install the following libraries:
# 1. Pandas
# 2. Requests
# 3. Matplotlib
#
# Follow this tutorial to install external libraries for your Jupyter notebook using the Anaconda Navigator.
#
# https://www.tutorialspoint.com/add-packages-to-anaconda-environment-in-python
#
# Once you are done, run the following cell. If it does nothing (i.e., if it throws no errors), then you may proceed.

# %%
# NON-EDITABLE CODE CELL
# You may run this cell, but do not edit it.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %% [markdown]
# ## Note
#
# 1. There is a good chance that you will have to look up how to do things using these libraries. This is fine. Just credit your sources appropriately.

# %% [markdown]
# ## Problem 1: Association Rules

# %% [markdown]
# ### Context
#
# You are a data consultant for a medium-sized grocery. Your job is to help the grocery's marketing and sales team identify the most frequent purchases of customers.

# %% [markdown]
# ### 1.1
#
# Read the file `sample order basket.csv` into a Pandas DataFrame called `df`.

# %%
# CODE CELL

# CODE START
filename="sample order basket.csv"
df=pd.read_csv(filename)
# CODE END

# %% [markdown]
# ### 1.2
#
# Create a "binary table" using a Pandas DataFrame. Save the DataFrame in a variable called `binary_table`.
#
# The specifications of the binary table are as follows:
# 1. The data in the binary table is based on the order log contained in `df`.
# 2. The index values of the binary table are the unique order IDs contained in the sales logs. These are arranged in ascending numerical order. Format the values as `int64`.
# 3. The column values of the binary table are the unique products contained in the sales logs. These are arranged in alphabetical order. Format the values as `object`.
# 4. The values of the binary table are either 0 or 1. A value will be 1 if the respective product is present in the respective order, and it will be 0 if the respective product is not present in the respective order. So, for example: if Order 5 ordered an apple, then the cell at row 5, column apple will have the value 1, and every other cell at row 5 will have the value 0.

# %%
# CODE CELL

# CODE START
binary_table=pd.DataFrame(df)
binary_table["OrderNum"]=binary_table["OrderNum"].astype('int')
binary_table["Product"]=binary_table["Product"].astype('object')
product=pd.get_dummies(df["Product"])    
prods=tuple(product)
for i in prods:
    binary_table[i]=product[i]

# CODE END

binary_table
# Out:
#       OrderNum Product  bread  cheese  eggs  flour  jam
# 0         1000    eggs      0       0     1      0    0
# 1         1001   bread      1       0     0      0    0
# 2         1002    eggs      0       0     1      0    0
# 3         1002   bread      1       0     0      0    0
# 4         1002   flour      0       0     0      1    0
# ...        ...     ...    ...     ...   ...    ...  ...
# 1068      1496   bread      1       0     0      0    0
# 1069      1497     jam      0       0     0      0    1
# 1070      1498   bread      1       0     0      0    0
# 1071      1499    eggs      0       0     1      0    0
# 1072      1499   bread      1       0     0      0    0
#
# [1073 rows x 7 columns]

# %% [markdown]
# ### 1.3
#
# Using `binary_table`, create a report. Store this report in a Pandas DataFrame called `report`.
#
# The specifications of the report are as follows:
# 1. The data in the report is based on the data in `binary_table`.
# 2. The index values of `report` are simply the defaults (i.e., counting up from 0 to whatever number).
# 3. `report` has two columns: `combination` and `count`. The `combination` column will contain tuples that describe an order combination (e.g., ("apple", "eggplant")). Format the `combination` column as `object`. The `count` column will contain an integer value describing the number of times that this combination appeared in the list of orders. Format the `count` column as `int64`.
# 4. Sort `reports` by `count` in descending order. The order of combinations within each count bracket does not matter.
#
# You may use any standard library from Python 3.8 that you feel is necessary to complete this item. (This just means that you can use any standard Python library as long as it was in Python 3.8).

# %%
# CODE CELL

# CODE START
#create a dictionary
combo_dict={}
for i in range(len(binary_table)):
    c=binary_table["OrderNum"][i] in combo_dict
    if c==True:
        combo_dict[binary_table["OrderNum"][i]].append(binary_table["Product"][i])
        combo_dict[binary_table["OrderNum"][i]].sort()
        
    else:   
        combo_dict[binary_table["OrderNum"][i]]=[binary_table["Product"][i]]

def find_combo(ordernum):
    return combo_dict[ordernum]
binary_table["combination"]=binary_table["OrderNum"].apply(find_combo)

def remove_list(combination):
    combi=""
    if len(combination)>1:
        for y in range(len(combination)-1):
            combi+=combination[y]+", "
        combi+=combination[len(combination)-1]
            
    else:
        combi+=combination[0]
    return combi
binary_table["combination"]=binary_table["combination"].apply(remove_list)
binary_table["combination"]=binary_table["combination"].astype('object')   

#table
reports=binary_table.loc[:,["combination","OrderNum"]].groupby(by="combination",as_index=False).count().rename(columns={"OrderNum":"count"})
reports=reports.sort_values(by="count",ascending=False)
report=pd.DataFrame(reports)   

# CODE END
report
# Out:
#                         combination  count
# 12                 bread, eggs, jam    138
# 15                       bread, jam    114
# 9                       bread, eggs     94
# 0                             bread     65
# 10               bread, eggs, flour     63
# 14                bread, flour, jam     54
# 11          bread, eggs, flour, jam     52
# 2               bread, cheese, eggs     51
# 8                bread, cheese, jam     36
# 26                        eggs, jam     34
# 25                 eggs, flour, jam     33
# 23                             eggs     31
# 13                     bread, flour     30
# 1                     bread, cheese     30
# 5          bread, cheese, eggs, jam     28
# 6              bread, cheese, flour     27
# 29                              jam     26
# 19         cheese, eggs, flour, jam     24
# 20                cheese, eggs, jam     24
# 7         bread, cheese, flour, jam     20
# 22                      cheese, jam     14
# 16                           cheese     13
# 28                       flour, jam     12
# 17                     cheese, eggs     12
# 3        bread, cheese, eggs, flour     12
# 24                      eggs, flour     10
# 4   bread, cheese, eggs, flour, jam     10
# 27                            flour      9
# 21                    cheese, flour      4
# 18              cheese, eggs, flour      3

# %% [markdown]
# ## Problem 2: A Plot of the International Space Station's Location

# %% [markdown]
# We will only be checking the final output of this problem.
#
# ### Context
#
# You are a budding data scientist aiming to try your new tools on real-world data. As a pet project, you have decided that you want to try plotting the latitude and longitude positions of the International Space Station on a chart.
#
# An "application programming interface" (API) is an interface (i.e., a point of connection/use) that a program offers to other pieces of software. APIs are how modern computer programs interact. To massively oversimplify the concept, modern applications send and receive HTTP requests and JSON-formatted data to talk to each other.
#
# We will be using the ISS position data API hosted at http://open-notify.org/Open-Notify-API/ISS-Location-Now/ for this item.
#
# You are expected to read the documentation of this API for this item.

# %% [markdown]
# ### 2.1
#
# Use the `requests` library and the `time` library to collect position data of the ISS at intervals of 10 seconds over the course of 30 minutes by sending GET requests to the ISS API endpoint.
#
# The specifications of this problem are as follows:
# 1. Send a GET request to the ISS API endpoint once every 10 seconds for 30 minutes.
# 2. Each time you send a GET request, append the returned data to a list called `iss_data`.
# 3. Save all the data to a file called `iss-data.json` so that you do not lose it. You may do this every time you get a request if you wish.
# 4. Do not modify the returned data per GET request.
# 5. The final file `iss-data.json` should contain roughly 180 data points.
#
# We will not be strict about the time intervals. We will only look at the chart that you produce from your data.

# %%
# CODE CELL
import time
import json
#request.get()
# CODE START
iss_data=[]
#10 second loop
start = time.time() #now
t_end = time.time() + 60 * 30 #loop for 30 mins
while time.time() < t_end:
    r=requests.get('http://api.open-notify.org/iss-now.json')
    iss_data.append(r.text)
    time.sleep(10)



with open('iss-data.json','w') as data:
    json.dump(iss_data, data,indent=2)

# CODE END
# Out:
# {"iss_position": {"latitude": "-21.9799", "longitude": "175.7763"}, "timestamp": 1627906842, "message": "success"}
# {"iss_position": {"latitude": "-22.4835", "longitude": "176.2237"}, "timestamp": 1627906853, "message": "success"}
# {"iss_position": {"latitude": "-22.9616", "longitude": "176.6530"}, "timestamp": 1627906863, "message": "success"}
# {"iss_position": {"latitude": "-23.4622", "longitude": "177.1075"}, "timestamp": 1627906873, "message": "success"}
# {"iss_position": {"latitude": "-23.9612", "longitude": "177.5657"}, "timestamp": 1627906884, "message": "success"}
# {"iss_position": {"latitude": "-24.4584", "longitude": "178.0277"}, "timestamp": 1627906894, "message": "success"}
# {"iss_position": {"latitude": "-24.9305", "longitude": "178.4716"}, "timestamp": 1627906904, "message": "success"}
# {"iss_position": {"latitude": "-25.4245", "longitude": "178.9416"}, "timestamp": 1627906915, "message": "success"}
# {"iss_position": {"latitude": "-25.9166", "longitude": "179.4159"}, "timestamp": 1627906925, "message": "success"}
# {"iss_position": {"latitude": "-26.3835", "longitude": "179.8716"}, "timestamp": 1627906935, "message": "success"}
# {"iss_position": {"latitude": "-26.8719", "longitude": "-179.6457"}, "timestamp": 1627906946, "message": "success"}
# {"iss_position": {"latitude": "-27.3583", "longitude": "-179.1583"}, "timestamp": 1627906956, "message": "success"}
# {"iss_position": {"latitude": "-27.8427", "longitude": "-178.6663"}, "timestamp": 1627906967, "message": "success"}
# {"iss_position": {"latitude": "-28.3020", "longitude": "-178.1933"}, "timestamp": 1627906977, "message": "success"}
# {"iss_position": {"latitude": "-28.7823", "longitude": "-177.6918"}, "timestamp": 1627906987, "message": "success"}
# {"iss_position": {"latitude": "-29.2603", "longitude": "-177.1852"}, "timestamp": 1627906998, "message": "success"}
# {"iss_position": {"latitude": "-29.7134", "longitude": "-176.6980"}, "timestamp": 1627907008, "message": "success"}
# {"iss_position": {"latitude": "-30.1868", "longitude": "-176.1813"}, "timestamp": 1627907018, "message": "success"}
# {"iss_position": {"latitude": "-30.6578", "longitude": "-175.6593"}, "timestamp": 1627907029, "message": "success"}
# {"iss_position": {"latitude": "-31.1263", "longitude": "-175.1317"}, "timestamp": 1627907039, "message": "success"}
# {"iss_position": {"latitude": "-31.5703", "longitude": "-174.6239"}, "timestamp": 1627907049, "message": "success"}
# {"iss_position": {"latitude": "-32.0338", "longitude": "-174.0850"}, "timestamp": 1627907060, "message": "success"}
# {"iss_position": {"latitude": "-32.4946", "longitude": "-173.5403"}, "timestamp": 1627907070, "message": "success"}
# {"iss_position": {"latitude": "-32.9525", "longitude": "-172.9897"}, "timestamp": 1627907081, "message": "success"}
# {"iss_position": {"latitude": "-33.3861", "longitude": "-172.4594"}, "timestamp": 1627907091, "message": "success"}
# {"iss_position": {"latitude": "-33.8384", "longitude": "-171.8965"}, "timestamp": 1627907102, "message": "success"}
# {"iss_position": {"latitude": "-34.2878", "longitude": "-171.3270"}, "timestamp": 1627907112, "message": "success"}
# {"iss_position": {"latitude": "-34.7128", "longitude": "-170.7787"}, "timestamp": 1627907122, "message": "success"}
# {"iss_position": {"latitude": "-35.1560", "longitude": "-170.1964"}, "timestamp": 1627907133, "message": "success"}
# {"iss_position": {"latitude": "-35.5959", "longitude": "-169.6073"}, "timestamp": 1627907143, "message": "success"}
# {"iss_position": {"latitude": "-36.0325", "longitude": "-169.0112"}, "timestamp": 1627907154, "message": "success"}
# {"iss_position": {"latitude": "-36.4451", "longitude": "-168.4368"}, "timestamp": 1627907164, "message": "success"}
# {"iss_position": {"latitude": "-36.8748", "longitude": "-167.8268"}, "timestamp": 1627907174, "message": "success"}
# {"iss_position": {"latitude": "-37.3008", "longitude": "-167.2094"}, "timestamp": 1627907185, "message": "success"}
# {"iss_position": {"latitude": "-37.7032", "longitude": "-166.6144"}, "timestamp": 1627907195, "message": "success"}
# {"iss_position": {"latitude": "-38.1218", "longitude": "-165.9822"}, "timestamp": 1627907205, "message": "success"}
# {"iss_position": {"latitude": "-38.5367", "longitude": "-165.3422"}, "timestamp": 1627907216, "message": "success"}
# {"iss_position": {"latitude": "-38.9474", "longitude": "-164.6943"}, "timestamp": 1627907226, "message": "success"}
# {"iss_position": {"latitude": "-39.3347", "longitude": "-164.0699"}, "timestamp": 1627907236, "message": "success"}
# {"iss_position": {"latitude": "-39.7372", "longitude": "-163.4063"}, "timestamp": 1627907247, "message": "success"}
# {"iss_position": {"latitude": "-40.1353", "longitude": "-162.7345"}, "timestamp": 1627907257, "message": "success"}
# {"iss_position": {"latitude": "-40.5104", "longitude": "-162.0868"}, "timestamp": 1627907267, "message": "success"}
# {"iss_position": {"latitude": "-40.8997", "longitude": "-161.3984"}, "timestamp": 1627907278, "message": "success"}
# {"iss_position": {"latitude": "-41.2844", "longitude": "-160.7014"}, "timestamp": 1627907288, "message": "success"}
# {"iss_position": {"latitude": "-41.6642", "longitude": "-159.9956"}, "timestamp": 1627907299, "message": "success"}
# {"iss_position": {"latitude": "-42.0213", "longitude": "-159.3154"}, "timestamp": 1627907309, "message": "success"}
# {"iss_position": {"latitude": "-42.3914", "longitude": "-158.5923"}, "timestamp": 1627907319, "message": "success"}
# {"iss_position": {"latitude": "-42.7562", "longitude": "-157.8602"}, "timestamp": 1627907330, "message": "success"}
# {"iss_position": {"latitude": "-43.0988", "longitude": "-157.1545"}, "timestamp": 1627907340, "message": "success"}
# {"iss_position": {"latitude": "-43.4531", "longitude": "-156.4046"}, "timestamp": 1627907350, "message": "success"}
# {"iss_position": {"latitude": "-43.8019", "longitude": "-155.6454"}, "timestamp": 1627907361, "message": "success"}
# {"iss_position": {"latitude": "-44.1450", "longitude": "-154.8768"}, "timestamp": 1627907372, "message": "success"}
# {"iss_position": {"latitude": "-44.4663", "longitude": "-154.1360"}, "timestamp": 1627907382, "message": "success"}
# {"iss_position": {"latitude": "-44.7979", "longitude": "-153.3490"}, "timestamp": 1627907392, "message": "success"}
# {"iss_position": {"latitude": "-45.1233", "longitude": "-152.5525"}, "timestamp": 1627907403, "message": "success"}
# {"iss_position": {"latitude": "-45.4425", "longitude": "-151.7464"}, "timestamp": 1627907413, "message": "success"}
# {"iss_position": {"latitude": "-45.7406", "longitude": "-150.9697"}, "timestamp": 1627907423, "message": "success"}
# {"iss_position": {"latitude": "-46.0472", "longitude": "-150.1449"}, "timestamp": 1627907434, "message": "success"}
# {"iss_position": {"latitude": "-46.3472", "longitude": "-149.3105"}, "timestamp": 1627907444, "message": "success"}
# {"iss_position": {"latitude": "-46.6265", "longitude": "-148.5069"}, "timestamp": 1627907454, "message": "success"}
# {"iss_position": {"latitude": "-46.9130", "longitude": "-147.6539"}, "timestamp": 1627907465, "message": "success"}
# {"iss_position": {"latitude": "-47.1924", "longitude": "-146.7914"}, "timestamp": 1627907475, "message": "success"}
# {"iss_position": {"latitude": "-47.4645", "longitude": "-145.9193"}, "timestamp": 1627907486, "message": "success"}
# {"iss_position": {"latitude": "-47.7169", "longitude": "-145.0800"}, "timestamp": 1627907496, "message": "success"}
# {"iss_position": {"latitude": "-47.9746", "longitude": "-144.1896"}, "timestamp": 1627907506, "message": "success"}
# {"iss_position": {"latitude": "-48.2245", "longitude": "-143.2900"}, "timestamp": 1627907517, "message": "success"}
# {"iss_position": {"latitude": "-48.4554", "longitude": "-142.4247"}, "timestamp": 1627907527, "message": "success"}
# {"iss_position": {"latitude": "-48.6899", "longitude": "-141.5075"}, "timestamp": 1627907537, "message": "success"}
# {"iss_position": {"latitude": "-48.9164", "longitude": "-140.5814"}, "timestamp": 1627907548, "message": "success"}
# {"iss_position": {"latitude": "-49.1245", "longitude": "-139.6914"}, "timestamp": 1627907558, "message": "success"}
# {"iss_position": {"latitude": "-49.3349", "longitude": "-138.7485"}, "timestamp": 1627907568, "message": "success"}
# {"iss_position": {"latitude": "-49.5367", "longitude": "-137.7973"}, "timestamp": 1627907579, "message": "success"}
# {"iss_position": {"latitude": "-49.7300", "longitude": "-136.8380"}, "timestamp": 1627907589, "message": "success"}
# {"iss_position": {"latitude": "-49.9145", "longitude": "-135.8709"}, "timestamp": 1627907600, "message": "success"}
# {"iss_position": {"latitude": "-50.0819", "longitude": "-134.9431"}, "timestamp": 1627907610, "message": "success"}
# {"iss_position": {"latitude": "-50.2490", "longitude": "-133.9615"}, "timestamp": 1627907620, "message": "success"}
# {"iss_position": {"latitude": "-50.4069", "longitude": "-132.9729"}, "timestamp": 1627907631, "message": "success"}
# {"iss_position": {"latitude": "-50.5489", "longitude": "-132.0249"}, "timestamp": 1627907641, "message": "success"}
# {"iss_position": {"latitude": "-50.6888", "longitude": "-131.0235"}, "timestamp": 1627907652, "message": "success"}
# {"iss_position": {"latitude": "-50.8192", "longitude": "-130.0162"}, "timestamp": 1627907662, "message": "success"}
# {"iss_position": {"latitude": "-50.9402", "longitude": "-129.0033"}, "timestamp": 1627907673, "message": "success"}
# {"iss_position": {"latitude": "-51.0464", "longitude": "-128.0336"}, "timestamp": 1627907683, "message": "success"}
# {"iss_position": {"latitude": "-51.1486", "longitude": "-127.0105"}, "timestamp": 1627907693, "message": "success"}
# {"iss_position": {"latitude": "-51.2410", "longitude": "-125.9829"}, "timestamp": 1627907704, "message": "success"}
# {"iss_position": {"latitude": "-51.3235", "longitude": "-124.9514"}, "timestamp": 1627907714, "message": "success"}
# {"iss_position": {"latitude": "-51.3929", "longitude": "-123.9654"}, "timestamp": 1627907724, "message": "success"}
# {"iss_position": {"latitude": "-51.4561", "longitude": "-122.9271"}, "timestamp": 1627907735, "message": "success"}
# {"iss_position": {"latitude": "-51.5093", "longitude": "-121.8858"}, "timestamp": 1627907745, "message": "success"}
# {"iss_position": {"latitude": "-51.5506", "longitude": "-120.8922"}, "timestamp": 1627907755, "message": "success"}
# {"iss_position": {"latitude": "-51.5841", "longitude": "-119.8470"}, "timestamp": 1627907766, "message": "success"}
# {"iss_position": {"latitude": "-51.6075", "longitude": "-118.8005"}, "timestamp": 1627907776, "message": "success"}
# {"iss_position": {"latitude": "-51.6208", "longitude": "-117.7531"}, "timestamp": 1627907787, "message": "success"}
# {"iss_position": {"latitude": "-51.6241", "longitude": "-116.7552"}, "timestamp": 1627907797, "message": "success"}
# {"iss_position": {"latitude": "-51.6176", "longitude": "-115.7074"}, "timestamp": 1627907807, "message": "success"}
# {"iss_position": {"latitude": "-51.6010", "longitude": "-114.6600"}, "timestamp": 1627907818, "message": "success"}
# {"iss_position": {"latitude": "-51.5757", "longitude": "-113.6637"}, "timestamp": 1627907828, "message": "success"}
# {"iss_position": {"latitude": "-51.5394", "longitude": "-112.6190"}, "timestamp": 1627907838, "message": "success"}
# {"iss_position": {"latitude": "-51.4930", "longitude": "-111.5763"}, "timestamp": 1627907849, "message": "success"}
# {"iss_position": {"latitude": "-51.4365", "longitude": "-110.5362"}, "timestamp": 1627907859, "message": "success"}
# {"iss_position": {"latitude": "-51.3735", "longitude": "-109.5481"}, "timestamp": 1627907869, "message": "success"}
# {"iss_position": {"latitude": "-51.2976", "longitude": "-108.5139"}, "timestamp": 1627907880, "message": "success"}
# {"iss_position": {"latitude": "-51.2118", "longitude": "-107.4836"}, "timestamp": 1627907890, "message": "success"}
# {"iss_position": {"latitude": "-51.1210", "longitude": "-106.5063"}, "timestamp": 1627907900, "message": "success"}
# {"iss_position": {"latitude": "-51.0162", "longitude": "-105.4845"}, "timestamp": 1627907911, "message": "success"}
# {"iss_position": {"latitude": "-50.9017", "longitude": "-104.4680"}, "timestamp": 1627907922, "message": "success"}
# {"iss_position": {"latitude": "-50.7776", "longitude": "-103.4569"}, "timestamp": 1627907932, "message": "success"}
# {"iss_position": {"latitude": "-50.6506", "longitude": "-102.4991"}, "timestamp": 1627907942, "message": "success"}
# {"iss_position": {"latitude": "-50.5082", "longitude": "-101.4997"}, "timestamp": 1627907953, "message": "success"}
# {"iss_position": {"latitude": "-50.3564", "longitude": "-100.5066"}, "timestamp": 1627907963, "message": "success"}
# {"iss_position": {"latitude": "-50.2033", "longitude": "-99.5671"}, "timestamp": 1627907973, "message": "success"}
# {"iss_position": {"latitude": "-50.0338", "longitude": "-98.5878"}, "timestamp": 1627907984, "message": "success"}
# {"iss_position": {"latitude": "-49.8553", "longitude": "-97.6156"}, "timestamp": 1627907994, "message": "success"}
# {"iss_position": {"latitude": "-49.6679", "longitude": "-96.6511"}, "timestamp": 1627908005, "message": "success"}
# {"iss_position": {"latitude": "-49.4814", "longitude": "-95.7398"}, "timestamp": 1627908015, "message": "success"}
# {"iss_position": {"latitude": "-49.2771", "longitude": "-94.7909"}, "timestamp": 1627908025, "message": "success"}
# {"iss_position": {"latitude": "-49.0645", "longitude": "-93.8505"}, "timestamp": 1627908036, "message": "success"}
# {"iss_position": {"latitude": "-48.8542", "longitude": "-92.9627"}, "timestamp": 1627908046, "message": "success"}
# {"iss_position": {"latitude": "-48.6255", "longitude": "-92.0392"}, "timestamp": 1627908056, "message": "success"}
# {"iss_position": {"latitude": "-48.3887", "longitude": "-91.1245"}, "timestamp": 1627908067, "message": "success"}
# {"iss_position": {"latitude": "-48.1440", "longitude": "-90.2188"}, "timestamp": 1627908077, "message": "success"}
# {"iss_position": {"latitude": "-47.9037", "longitude": "-89.3648"}, "timestamp": 1627908087, "message": "success"}
# {"iss_position": {"latitude": "-47.6440", "longitude": "-88.4773"}, "timestamp": 1627908098, "message": "success"}
# {"iss_position": {"latitude": "-47.3769", "longitude": "-87.5990"}, "timestamp": 1627908108, "message": "success"}
# {"iss_position": {"latitude": "-47.1156", "longitude": "-86.7714"}, "timestamp": 1627908118, "message": "success"}
# {"iss_position": {"latitude": "-46.8343", "longitude": "-85.9116"}, "timestamp": 1627908129, "message": "success"}
# {"iss_position": {"latitude": "-46.5459", "longitude": "-85.0613"}, "timestamp": 1627908139, "message": "success"}
# {"iss_position": {"latitude": "-46.2505", "longitude": "-84.2205"}, "timestamp": 1627908150, "message": "success"}
# {"iss_position": {"latitude": "-45.9630", "longitude": "-83.4287"}, "timestamp": 1627908160, "message": "success"}
# {"iss_position": {"latitude": "-45.6547", "longitude": "-82.6067"}, "timestamp": 1627908170, "message": "success"}
# {"iss_position": {"latitude": "-45.3398", "longitude": "-81.7942"}, "timestamp": 1627908181, "message": "success"}
# {"iss_position": {"latitude": "-45.0340", "longitude": "-81.0293"}, "timestamp": 1627908191, "message": "success"}
# {"iss_position": {"latitude": "-44.7069", "longitude": "-80.2355"}, "timestamp": 1627908202, "message": "success"}
# {"iss_position": {"latitude": "-44.3737", "longitude": "-79.4512"}, "timestamp": 1627908212, "message": "success"}
# {"iss_position": {"latitude": "-44.0346", "longitude": "-78.6765"}, "timestamp": 1627908223, "message": "success"}
# {"iss_position": {"latitude": "-43.7063", "longitude": "-77.9474"}, "timestamp": 1627908233, "message": "success"}
# {"iss_position": {"latitude": "-43.3560", "longitude": "-77.1908"}, "timestamp": 1627908243, "message": "success"}
# {"iss_position": {"latitude": "-43.0001", "longitude": "-76.4433"}, "timestamp": 1627908254, "message": "success"}
# {"iss_position": {"latitude": "-42.6388", "longitude": "-75.7050"}, "timestamp": 1627908264, "message": "success"}
# {"iss_position": {"latitude": "-42.2899", "longitude": "-75.0105"}, "timestamp": 1627908274, "message": "success"}
# {"iss_position": {"latitude": "-41.9185", "longitude": "-74.2901"}, "timestamp": 1627908285, "message": "success"}
# {"iss_position": {"latitude": "-41.5421", "longitude": "-73.5785"}, "timestamp": 1627908295, "message": "success"}
# {"iss_position": {"latitude": "-41.1790", "longitude": "-72.9090"}, "timestamp": 1627908305, "message": "success"}
# {"iss_position": {"latitude": "-40.7931", "longitude": "-72.2144"}, "timestamp": 1627908316, "message": "success"}
# {"iss_position": {"latitude": "-40.4026", "longitude": "-71.5285"}, "timestamp": 1627908326, "message": "success"}
# {"iss_position": {"latitude": "-40.0076", "longitude": "-70.8512"}, "timestamp": 1627908337, "message": "success"}
# {"iss_position": {"latitude": "-39.6272", "longitude": "-70.2138"}, "timestamp": 1627908347, "message": "success"}
# {"iss_position": {"latitude": "-39.2235", "longitude": "-69.5525"}, "timestamp": 1627908357, "message": "success"}
# {"iss_position": {"latitude": "-38.8156", "longitude": "-68.8993"}, "timestamp": 1627908368, "message": "success"}
# {"iss_position": {"latitude": "-38.4037", "longitude": "-68.2541"}, "timestamp": 1627908378, "message": "success"}
# {"iss_position": {"latitude": "-37.9878", "longitude": "-67.6169"}, "timestamp": 1627908389, "message": "success"}
# {"iss_position": {"latitude": "-37.5880", "longitude": "-67.0171"}, "timestamp": 1627908399, "message": "success"}
# {"iss_position": {"latitude": "-37.1645", "longitude": "-66.3946"}, "timestamp": 1627908409, "message": "success"}
# {"iss_position": {"latitude": "-36.7373", "longitude": "-65.7796"}, "timestamp": 1627908420, "message": "success"}
# {"iss_position": {"latitude": "-36.3270", "longitude": "-65.2007"}, "timestamp": 1627908430, "message": "success"}
# {"iss_position": {"latitude": "-35.8929", "longitude": "-64.6000"}, "timestamp": 1627908440, "message": "success"}
# {"iss_position": {"latitude": "-35.4554", "longitude": "-64.0063"}, "timestamp": 1627908451, "message": "success"}
# {"iss_position": {"latitude": "-35.0145", "longitude": "-63.4196"}, "timestamp": 1627908461, "message": "success"}
# {"iss_position": {"latitude": "-34.5917", "longitude": "-62.8671"}, "timestamp": 1627908472, "message": "success"}
# {"iss_position": {"latitude": "-34.1444", "longitude": "-62.2933"}, "timestamp": 1627908482, "message": "success"}
# {"iss_position": {"latitude": "-33.6942", "longitude": "-61.7261"}, "timestamp": 1627908493, "message": "success"}
# {"iss_position": {"latitude": "-33.2627", "longitude": "-61.1920"}, "timestamp": 1627908503, "message": "success"}
# {"iss_position": {"latitude": "-32.8068", "longitude": "-60.6372"}, "timestamp": 1627908513, "message": "success"}
# {"iss_position": {"latitude": "-32.3480", "longitude": "-60.0885"}, "timestamp": 1627908524, "message": "success"}
# {"iss_position": {"latitude": "-31.8863", "longitude": "-59.5457"}, "timestamp": 1627908534, "message": "success"}
# {"iss_position": {"latitude": "-31.4443", "longitude": "-59.0344"}, "timestamp": 1627908544, "message": "success"}
# {"iss_position": {"latitude": "-30.9777", "longitude": "-58.5031"}, "timestamp": 1627908555, "message": "success"}
# {"iss_position": {"latitude": "-30.5084", "longitude": "-57.9774"}, "timestamp": 1627908565, "message": "success"}
# {"iss_position": {"latitude": "-30.0593", "longitude": "-57.4819"}, "timestamp": 1627908575, "message": "success"}
# {"iss_position": {"latitude": "-29.5852", "longitude": "-56.9666"}, "timestamp": 1627908586, "message": "success"}
# {"iss_position": {"latitude": "-29.1089", "longitude": "-56.4568"}, "timestamp": 1627908596, "message": "success"}
# {"iss_position": {"latitude": "-28.6304", "longitude": "-55.9520"}, "timestamp": 1627908607, "message": "success"}
# {"iss_position": {"latitude": "-28.1726", "longitude": "-55.4760"}, "timestamp": 1627908617, "message": "success"}
# {"iss_position": {"latitude": "-27.6897", "longitude": "-54.9808"}, "timestamp": 1627908627, "message": "success"}
# {"iss_position": {"latitude": "-27.2048", "longitude": "-54.4904"}, "timestamp": 1627908638, "message": "success"}

# %% [markdown]
# ### 2.2
#
# Using the data you gathered and stored in `iss-data.json`, make a `matplotlib` plot of the location data.
#
# The specifications of this problem are as follows:
# 1. Use the longitude and latitude data contained in `iss-data.json` as your data.
# 2. Plot this data on a `matplotlib` plot that appropriately visualizes the data. It is up to you what specific plot you want to use as long as we, the human readers of your report, understand the message of your plot.
# 3. Use latitude as the X axis and longitude as the Y axis.
# 4. VERY IMPORTANT: Make sure that the chart displays in your Jupyter notebook before you submit.
#
# We will only check the chart. We do not care how you make it display as long as you follow the specifications.

# %%
# CODE CELL

# CODE START

plt.figure(figsize=(30, 30), dpi=100)
plt.xlabel("Latitude")
plt.ylabel("Longitude")
plt.title("ISS Location Data")
remove="{},'\"’"
remove=list(remove)
with open('iss-data.json','r') as iss_data:
    data=json.loads(iss_data.read())

for i in range(len(data)):
    split=data[i].split()
    x=split[4]
    y=split[6]
    for z in range (len(remove)):
            a=x.find(remove[z])
            if a!=-1:
                x=x.replace(remove[z],"")
                
    x=round(float(x),2)
    for z in range (len(remove)):
            b=y.find(remove[z])
            if b!=-1:
                y=y.replace(remove[z],"")
    y=round(float(y),2)
        
    plt.scatter(x, y)

# CODE END
